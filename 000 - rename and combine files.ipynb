# %%
# SMI Eye tracker files
# joint + rename
# from：Event Export_105-1-recording_105-1-recording.txt and Event Export_105-2-recording_105-2-recording.txt
# to: 105_1_etg.txt

subject = '126'
#root = 'F:/Eye-Hand Coordination-JXH/'+subject+'/ETG/'
root = 'F:/Eye-Hand Coordination-JXH/4 Experiment data/1 Raw data/'+subject+'/ETG/'


# SMI Eye tracker files
# joint + rename
# from：Event Export_105-1-recording_105-1-recording.txt and Event Export_105-2-recording_105-2-recording.txt
# to: 105_1_etg.txt

for i in [1,3,5,7]:
#for i in [2,4,6,8]:
#for i in [3,5,7,9]:
#for i in [12,14,16,18]:
#for i in [10,12,14,16]:
    fresult = root+subject+'_'+str(int((i+1)/2))+'_etg.txt'
    f1 = root+'Event Export_'+subject+'-'+str(i)+'-recording_'+subject+'-'+str(i)+'-recording.txt'
    f2 = root+'Event Export_'+subject+'-'+str(i+1)+'-recording_'+subject+'-'+str(i+1)+'-recording.txt'
    if i != 7:
    #if i != 8:
    #if i != 9:
    #if i != 18:
    #if i != 16:
        with open(f1,'r') as fa:
            with open(f2,'r') as fb:
                with open(fresult,'w') as fc:
                    for line1 in fa:
                        fc.write(line1)
                    for line2 in fb:
                        fc.write(line2)
    else:
        f3 = root+'Event Export_'+subject+'-'+str(i+2)+'-recording_'+subject+'-'+str(i+2)+'-recording.txt'
        count = 0
        with open(f1,'r') as fa:
            with open(f2,'r') as fb:
                with open(f3,'r') as fc:
                    with open(fresult,'w') as fd:
                        for line1 in fa:
                            fd.write(line1)
                        for line2 in fb:
                            fd.write(line2)
                        for line3 in fc:
                            fd.write(line3)

# %%
# SMI Eye tracker files
# joint + rename
# from：Raw Data Export_105-1-recording_105-1-recording.txt and Raw Data Export_105-2-recording_105-2-recording.txt
# to: 105_1_raw.txt

#root = 'D:/Eye-Hand Coordination-JXH/'+subject+'/ETG/'


for i in [1,3,5,7]:
#for i in [2,4,6,8]:
#for i in [3,5,7,9]:
#for i in [12,14,16,18]:
#for i in [10,12,14,16]:
    fresult = root+subject+'_'+str(int((i+1)/2))+'_raw.txt'
    f1 = root+'Raw Data Export_'+subject+'-'+str(i)+'-recording_'+subject+'-'+str(i)+'-recording.txt'
    f2 = root+'Raw Data Export_'+subject+'-'+str(i+1)+'-recording_'+subject+'-'+str(i+1)+'-recording.txt'
    if i != 7:
    #if i != 8:
    #if i != 9:
    #if i != 18:
    #if i != 16:
        linenum = 0
        with open(f1,'r') as fa:
            with open(f2,'r') as fb:
                with open(fresult,'w') as fc:
                    for line1 in fa:
                        fc.write(line1)
                    for line2 in fb:
                        linenum = linenum + 1
                        if linenum != 1:
                            #跳过linenum=1，即后表的表头
                            fc.write(line2)
    else:
        f3 = root+'Raw Data Export_'+subject+'-'+str(i+2)+'-recording_'+subject+'-'+str(i+2)+'-recording.txt'
        linenum2 = 0
        linenum3 = 0
        with open(f1,'r') as fa:
            with open(f2,'r') as fb:
                with open(f3,'r') as fc:
                    with open(fresult,'w') as fd:
                        for line1 in fa:
                            fd.write(line1)
                            lastline1 = line1
                        for line2 in fb:
                            linenum2 = linenum2 + 1
                            if linenum2 != 1:
                                fd.write(line2)
                                lastline2 = line2
                        for line3 in fc:
                            linenum3 = linenum3 + 1
                            if linenum3 != 1:
                                fd.write(line3)

# %%
# smartphone files
# rename
# from：105_1_2018-09-03,1713145820.txt
# to: 101_1_calibration_1234.txt/csv
import os

subject = '133'
root = 'F:/Eye-Hand Coordination-JXH/4 Experiment data/1 Raw data/'+subject+'/phone/'


for filename in os.listdir(root):
    #for i in [1,2,3,4]:
    for i in [1]:
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('0.txt'):
            fresult = root+subject+'_'+str(i)+'_calibration_1234.csv'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('1.txt'):
            fresult = root+subject+'_'+str(i)+'.txt'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('2.txt'):
            fresult = root+subject+'_'+str(i)+'_withkeyup.txt'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('3.txt'):
            fresult = root+subject+'_'+str(i)+'_calibration_enter.csv'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)

# %%
# smartphone files
# rename
# from：114_2_calibration_1234.txt
# to: 114_2_calibration_1234.csv

import os

#root = 'D:/Eye-Hand Coordination-JXH/'+subject+'/phone/'
subject = '133'
root = 'F:/Eye-Hand Coordination-JXH/4 Experiment data/1 Raw data/'+subject+'/phone/'

for filename in os.listdir(root):
    for i in [1,2,3,4]:
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('_calibration_1234.txt'):
            fresult = root+subject+'_'+str(i)+'_calibration_1234.csv'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)
        if filename.startswith(subject+'_'+str(i)) and filename.endswith('_calibration_enter.txt'):
            fresult = root+subject+'_'+str(i)+'_calibration_enter.csv'
            with open(root+filename,'r') as fa:
                with open(fresult,'w') as fc:
                    for line in fa:
                        fc.write(line)
